# %%
print("hi")
# Out:
# hi

# %%
name = "한빛페이"    # str
count = 5            # int
rate = 0.1           # float
is_ok = True         # bool

print(name, count, rate, is_ok)
print(type(count), type(rate))
# Out:
# 한빛페이 5 0.1 True
# <class 'int'> <class 'float'>

# %%
age = "25"           # 문자열로 받음
# print(age + 1)     # TypeError 확인 (일부러 오류)
print(int(age) + 1)  # 26  ← 형변환으로 해결
print(f"나는 {age}살")  # 나는 25살
print(10 // 3, 10 % 3)  # 3  1  (몫, 나머지)
# Out:
# 26
# 나는 25살
# 3 1
